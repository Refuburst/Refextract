# %%
from refextract import extract_references_from_file
import tkinter as tk
from tkinter import filedialog
from IPython.display import HTML, display
import re
import fitz  # PyMuPDF
import numpy as np
import nltk

# %%
def extract_text_from_pdf(pdf_path):
    try:
        cite_text =''
        pdf_document = fitz.open(pdf_path)

        for page_num in range(pdf_document.page_count):
            page = pdf_document.load_page(page_num)
            cite_text += page.get_text("text")#concatinate text from each page
        pdf_document.close()
        return cite_text
    except fitz.FileNotFoundError:
        return "File not found or inaccessible"

# %%
citation_text =extract_text_from_pdf("C:\\Users\\Glen\\OneDrive - Teesside University\\CIS4006 Advanced Practice\\External Students\\test.pdf")

# %%
print(citation_text)
# Out:
# garciaTitle: Reflective Report - Data Analyst Experience at CEDAR HEALTH AND
# WELLBEING
# 1. Introduction
# Working as a Data Analyst at CEDAR HEALTH AND WELLBEING from August to
# December, I plunged myself into a deep and enriching experience within the healthcare field,
# with particular attention to individuals struggling with learning disabilities and Autism. My
# responsibilities were not limited to typical data analysis but also included the complexities of
# healthcare dynamics and how technology can interface with compassionate patient care. This
# reflective report aims to unravel the complex facets of my role, shedding light on the
# overarching objectives that guided my data analysis endeavours, detailing the diverse activities
# undertaken, and examining the consequential impact of my contributions to the broader
# organizational landscape.
# This transformative journey enabled me to intertwine technical proficiency with an in-depth
# comprehension of the peculiar difficulties faced by this demographic so that my analytical
# insights align with the broader purpose of improving the quality of life for individuals under
# the care of CEDAR HEALTH AND WELLBEING.
# Figure 1 showing a data analyst working
# Commented [GH1]: Please have a title Page and a TOC
# page
# Commented [GH2]: Left Justify to margin - do not
# indent...
#
# 1.1. Objectives of the Data Analyst Role
# In my capacity as a Data Analyst at CEDAR HEALTH AND WELLBEING, my main role was
# to identify valuable information from various datasets that are related to those who have
# learning disabilities and Autism. Thus, the desire to optimize all improving-care activities of
# CEDAR HEALTH AND WELLBEING becomes more and more essential in contemporary
# healthcare (Dubois, 2018). After a thorough examination of datasets such as patient medical
# records, treatment outcomes, and demographic data to uncover patterns, correlations, or trends
# that would inform strategic decision-making processes.
# For instance, a careful analysis of datasets concentrating on medication adherence among
# patients with learning disabilities helped me uncover patterns affecting the efficacy of
# treatments. Furthermore, processing demographical datasets provided a subtle insight into
# patient profiles enabling more precise tailoring of care plans to accommodate specific needs.
# Using this broad perspective in data analysis made a large contribution to the overall goal of
# enhancing healthcare approaches and consequently promoting the health conditions among
# people under CEDAR HEALTH AND WELLBEING’s.
#
# 2. Activities Undertaken
# In this section, I will outline the key activities and responsibilities undertaken during my stay
# as a Data Analyst at CEDAR HEALTH AND WELLBEING.
# 2.1. Data Collection and Processing
# I was also supposed to collect and process healthcare data, ensuring that it was correct and
# relevant. Working with the healthcare professionals, I collected information that helped me
# achieve a holistic understanding of how individuals suffering from learning disabilities and
# Autism (Williams & Evans, 2019).
#
# Figure 2 depicting the data analysis process.
# 2.2. Statistical Analysis
# By using statistical approaches, I performed thorough studies to ascertain patterns, trends, and
# correlations between the datasets. This statistical approach attempted to reveal insights that
# could guide decision-making processes and improve the quality of care offered by a healthcare
# organization (Garcia & Martinez, 2020).
# 2.3. Report Generation
# I played a pivotal role in generating reports based on the analyzed data. These reports were
# utilized by healthcare professionals, management, and stakeholders to assess the effectiveness
# of current practices and make informed decisions to improve the overall well-being of
# individuals in the care of CEDAR HEALTH AND WELLBEING (Lee & Smith, 2017).
# 2.4. Data Visualization
# To facilitate a better understanding of complex healthcare data, I engaged in data visualization
# techniques. Creating charts, graphs, and dashboards, I presented the findings in a visually
# comprehensible manner, aiding both technical and non-technical stakeholders in grasping the
# significance of the data (Gupta., 2021).
# To make things easier for everyone to understand the data, I used data visualization
# techniques. I created charts, graphs, and dashboards to present the findings more visually
# understandable form so that both technical as well as non-technical stakeholders could easily
# see the importance of data (Brown et al., 2021).
# Commented [GH3]: Why the full stop?
#
# 2.5. Continuous Improvement Initiatives
# Throughout my role, I actively engaged in initiatives aimed at improving data collection
# processes and enhancing the overall efficiency of data analysis. This involved collaborating
# with the IT team to implement advanced tools and technologies that streamlined the data
# analysis workflow (White & Davis, 2019).
#
#
#
#
#
# Figure 3 Visuals created during my time at Cedar Health and Well-being
# 3. Impact of Data Analysis Contributions
# The impact of my data analysis contributions on CEDAR HEALTH AND WELLBEING and
# the individuals under its care is noteworthy, encompassing various facets of organizational and
# patient outcomes.
# 3.1. Enhanced Decision-Making
# The provision of accurate and insightful data analyses significantly contributed to informed
# decision-making processes within the organization (Morgan & Adams, 2020). These analyses
# played a pivotal role in shaping healthcare strategies tailored for individuals with learning
# disabilities and Autism.
# I remember, in a specific unit catering to individuals with Autism, the healthcare team noticed
# variations in treatment responses among patients undergoing a particular therapeutic
# intervention. I and some colleagues, through rigorous analysis of patient records, identified
# patterns indicating that individuals with certain learning disabilities responded more positively
# to alternative therapies. This insight prompted the healthcare team to reassess their approach
# and consider personalized therapeutic plans based on the specific needs and responsiveness of
# each individual. By tailoring interventions to align with the data-driven findings, the team
# observed improved outcomes, reduced adverse effects, and enhanced patient satisfaction.
# 3.2. Improved Patient Care
# The data-driven insights derived from my analyses played a crucial role in enhancing the
# quality of patient care (Phillips, 2018). Healthcare professionals were empowered to tailor
# interventions based on individual needs, fostering a more personalized and effective care
# approach.
#
# 3.3. Efficiency Gains
# A continuous improvement strategy was implemented that improved the efficiency of data
# analysis workflow, saving time and providing rapid response to emerging healthcare trends and
# challenges (Parker, 2021).
# 3.4. Positive Organizational Impact
# The reports and visualizations generated during my when I was a Data Analyst there had a
# positive impact on the organization (White & Davis, 2019). Stakeholders, including
# management and external partners, gained a clearer understanding of the organization's
# performance and its commitment to data-driven decision-making.
#
#
#
#
# Figure 4 showing the positive outcomes through my data analysis
# 4. Reflection
# Reflecting on my experience as a Data Analyst at CEDAR HEALTH AND WELLBEING
# reveals key insights and personal growth areas that have contributed to both my professional
# and personal development. My professional life in data analysis at CEDAR HEALTH AND
# WELLBEING was a period of significant personal and career growth. While being a
# challenging immersion, it turned out to be very rewarding as I gained an in-depth set of skills
# in data analytics and insight generation.
# I polished my skills in statistical analysis tools, data processing techniques, and methods of
# data visualization while navigating through different datasets in the field of healthcare. Data
# cleansing and the complexity surrounding data quality became a vital concern, reflective of the
# complications arising from comprehensiveness with healthcare data.
# Working with healthcare professionals and the larger team required strong communication
# skills. Subsequently, regular meetings and feedback sessions became the basis for matching
# data analysis outcomes with the organization’s healthcare goals. This collaborative approach
# not only made me better prepared to present complicated analytical findings but also facilitated
# an engaging creative fusion between the technical and non-technical stakeholders. Healthcare
# data analysis was also dynamic, and therefore they required problem-solving skills as well as
# effective time use. Juggling multiple tasks and deadlines turned into second nature as I
# endeavored to streamline the processes of data interpretation, while also being prompt when it
# came to adapting my responses based on new developments in healthcare.
# Thus, my work as a Data Analyst at CEDAR HEALTH AND WELLBEING could be described
# best in terms of a transformative journey that is both challenging and rewarding in healthcare
# dynamics.
#
# 4.1. Technical Skill Development
# The role provided a platform for enhancing technical skills in data analysis, statistical methods,
# and data visualization tools (Johnson & Brown, 2019). Navigating through diverse datasets
# improved my proficiency in extracting meaningful insights.
# Healthcare data, like most things in the healthcare sector, is dynamic and no issue would be
# handled without taking into consideration several things including subtle patterns and trends
# emerging from meticulous analysis. Statistical methods were applied not only as a regime of
# abstract thought but also as an essential instrument that shaped the strategic direction for
# decisions regarding healthcare interventions. It was like a crucible, within which the art of
# distilling meaningful information from such datasets could be finely honed while combining
# technical expertise with a more significant aim to increase quality in care delivered by
# CEDARHEALTH AND WELLBEING. It also highlighted the critical intersection between
# developing technical skills and realizing the immediate effects of data-guided decisions in
# healthcare.
# 4.2. Understanding Healthcare Dynamics
# Interacting with healthcare professionals improved my knowledge about the complex aspects
# of providing care to people suffering from learning disabilities and Autism (Nelson & Smith,
# 2017). This experience widened my outlook concerning the link between data and healthcare
# delivery. For instance, in particular cases such as discussions with healthcare professionals’ a
# certain case was observed when practice data analysis of patient records demonstrated patterns
# in the effectiveness of the use of different intervention strategies. This real-life case showed
# how insights from data improved and perfected the care planning for individuals with learning
# disabilities. Such occurrences emphasized the importance of my position as a Data Analyst in
# enhancing healthcare outcomes.
# Commented [GH4]: This is a bit repetitive and not sure
# why it is all capitalised...
# 4.3. Challenges Encountered
# Challenges involved in navigating the healthcare data included the need for thorough data
# cleansing and addressing data quality issues (Garcia & Martinez, 2020). Overcoming these
# challenges strengthened my problem-solving skills and resilience.
# One particular case happened when dealing with discrepancies in the patient records, where
# inconsistent
# data
# entry
# adversely
# affected
# the
# results
# of
# the
# analysis.
# To tackle this problem, I worked closely with the IT team and healthcare professionals in
# implementing a strict data-cleaning procedure. This real-life case demonstrated that poor data
# quality directly translated into unreliable analytical results. Through thorough data validation
# steps and ongoing improvements, we managed to boost the precision of our analytical insights
# so that not merely were they meaningful but also trustworthy.
# 4.4. Time Management and Prioritization
# The dynamic nature of healthcare data analysis requires effective time management and
# prioritization (Brown et al., 2021). Balancing multiple tasks and deadlines improved my ability
# to prioritize and manage time efficiently.
# One important project concerned the urgent situation of analyzing a large dataset with
# significant data that pertained to the medication preferences of people suffering from learning
# disabilities. In parallel, another project aimed at evaluating the effectiveness of current data
# collection practices was developing. This situation necessitated careful planning and ranking
# of priorities.
# To address this problem, I used a systematic method. First, I did a thorough evaluation of both
# projects to determine the priorities and their respective deadlines. Because the medication
# preferences analysis is time-sensitive, I allotted particular windows of my day to immerse
# myself into such a dataset in order not to be distracted by other issues and to carry out this
# analysis promptly. Also, there was a strategic timing for the data collection efficiency project
# when some periods of lesser urgency were allocated allowing balance and order in the
# works. Management of time effectively This real-world application in both projects not only
# led to their completion successfully but also highlighted the significance that adaptability can
# play when dealing with changing requirements for healthcare data analysis. This experience
# greatly developed my ability to handle several tasks without sacrificing the quality of work.
#
# 4.5. Collaboration and Communication
# The role depended on effective collaboration and communication with the healthcare
# professionals. I managed to overcome communication barriers and customize how data were
# presented to stakeholders, thus developing my interpersonal skills as well as my ability to
# communicate effectively (Robinson & Nelson, 2018).
# 4.6. Personal Growth
# I achieved significant personal growth from the experience at CEDAR HEALTH AND
# WELLBEING. During the process, I learned to deal responsibly with sensitive healthcare data
# and developed a new understanding of how important it is to analyze data to guide health
# outcomes (Anderson, 2019).
#
#
#
#
#
# 5. Personal Benefits
# Working as a Data Analyst at CEDAR HEALTH AND WELLBEING yielded numerous
# personal benefits that extend beyond technical skills.
# 5.1. Sense of Purpose
# A huge sense of purpose came from contributing to improved health outcomes for people with
# learning disabilities and Autism. It was fulfilling, personally for me to know that my analyses
# contributed to the betterment of their quality of life.
# 5.2. Skill Diversification
# The role allowed for the diversification of skills beyond technical competencies. I gained
# insights into healthcare administration, compliance, and the ethical considerations surrounding
# healthcare data (Wright & Martinez, 2020).
# 5.3. Professional Networking
# Communicating with healthcare professionals created potentially beneficial professional
# relationships. Working with various teams expanded my circle of acquaintances and
# familiarized me with terms within the healthcare industry (Robinson & Adams, 2019).
# 5.4. Continuous Learning
# Due to the dynamic nature of healthcare data and changing trends in the industry, continuous
# learning was required. As the field of data analysis methodologies and healthcare practices
# continued to shift, staying up-to-date helped me remain mentally engaged. (Kovalenko &
# White 2021). This helped me stay intellectually stimulated by following developments in both
# data analysis methodologies and healthcare practices (Hall & Baker, 2018).
#
# 6. Professional Values and Behaviour
# In this section, I will discuss the professional values and behavior exhibited during my role as
# a Data Analyst at CEDAR HEALTH AND WELLBEING.
# 6.1. Integrity and Ethics
# Maintaining the highest standards of integrity and ethics was paramount in handling healthcare
# data. Adhering to privacy regulations and ensuring the ethical use of data underscored the trust
# placed in the data analysis process (Lee & Martin, 2021).
# For instance, maintaining high standards of integrity and ethics as a Data Analyst at CEDAR
# HEALTH AND WELLBEING in practice meant putting stringent mechanisms to safeguard
# private healthcare information. I remember, when working with patient records and treatment
# information I always made certain that privacy regulations like the Health Insurance Portability
# and Accountability Act (HIPAA) were maintained. This encompassed the use of encryption
# protocols for data storage, limiting access to personnel authorized; regular audits were also
# done to point out possible vulnerabilities in the system and remedy them.
# In addition, I was actively involved in the formulation and implementation of organizational
# policies that centered on the ethical use of data. For example, when faced with a situation where
# divulging specific data could potentially compromise patient confidentiality, I argued for one
# that would be more secure and privacy-preserving. This dedication to ethical decision-making,
# not only aligned with the guidelines of industry regulations but also showed a forward-thinking
# attitude in being a trustworthy and confident worthy organization as well pupils were under its
# care.
#
#
# Commented [GH5]: British english…
# 6.2. Collaboration and Teamwork
# Teamwork was demonstrated through collaboration with healthcare professionals and other
# team members. Open communication and the spirit of collaboration were crucial to successful
# data analysis projects (Johnson & Martinez, 2020; Robinson& Davis, 2019).
# 6.3. Accountability
# Taking accountability for the accuracy and reliability of data analyses demonstrated a
# commitment to delivering high-quality insights. This accountability extended to addressing any
# discrepancies and continuously improving data quality (Hall et al., 2018; Anderson & Turner,
# 2020).
# 6.4. Adaptability
# The healthcare sector's dynamic nature requires adaptability to changing circumstances.
# Embracing change and adapting data analysis strategies to evolving healthcare needs
# showcased flexibility and resilience (Gray & Coleman, 2017).
# 6.5. Continuous Improvement
# Engaging in continuous improvement initiatives highlighted a commitment to enhancing
# processes and outcomes. A proactive approach to identifying areas for improvement
# contributed to the organization's overall growth (Green, 2018).
#
#
#
#
#
# Commented [GH6]: space
# Commented [GH7]: et al.
# Commented [GH8R7]: But only for more than three
# authors
# 7. Conclusion
# In the end, the period I worked as a Data Analyst at CEDAR HEALTH AND WELLBEING
# was an enriching journey combining strong technical skills and a deep understanding of
# complex healthcare processes. This role was not simply about applying and polishing data
# analysis skills; it served as a fire where personal and professional development could take place
# on an expansive scale. The resulting impact of data-based decision-making on patient care,
# organizational effectiveness, and the overall healthcare strategy inherently highlights how
# paramount this practice is within the healthcare sector.
# Without a doubt, the various tasks I performed during my time there highlighted the hands-on
# nature of data analytics in defining healthcare outcomes. The depth and scope of that which
# was analyzed together with the strategic insights found were instrumental in informed decision-
# making processes. This was not just an issue for the organizational hierarchy but profoundly
# influenced strategies that were formulated at all levels to cater to individuals who received care
# from CEDAR HEALTH AND WELLBEING. The congruence between data analysis and
# healthcare strategies became manifest as a tangible improvement in the quality of patient care,
# reflective both of technical awareness on one hand and compassionate provisioning on the other
# (Turner & Martinez, 2019)
# This highlights the dynamic interaction of technical knowledge, human interactive skills as
# well as a high level of responsibility to be able to work with confidential data about health. This
# experience indicates the crucial position that data analysts hold in directing healthcare
# organizations toward attaining maximum benefits when such critical transformations occur
# within the health industry, where untold levels of innovation and basic metamorphosis are
# apparent. This journey was also instrumental in obtaining a wise understanding of healthcare
# ideas and implanting a very resilient ethic, that is the capacity to react constructively to
# Commented [GH9]: Make Headings larger font
# challenges while meaningfully contributing to noble causes aimed at healthcare quality
# betterment (White & Adams 2017).
# In sum, the role of a Data Analyst at CEDAR HEALTH AND WELLBEING was more than
# just a stage of professional growth, it was also a vibrant diverse experience for all sorts of
# technical acumen and compassionate care delivery that resonated on organizational, strategic,
# and personal levels.
#
# 8. Recommendations for Future Data Analysis Initiatives
# Based on my experience, I recommend the following for future data analysis initiatives at
# CEDAR HEALTH AND WELLBEING:
# 8.1. Advanced Training
# Providing continuous training opportunities in advanced data analysis methodologies and tools
# will empower analysts to stay at the forefront of industry advancements.
# 8.2. Interdepartmental Collaboration
# Encouraging increased collaboration between the data analysis team and various healthcare
# departments will ensure a more comprehensive understanding of data needs and facilitate more
# targeted analyses.
# 8.3. Data Governance Framework
# Establishing a robust data governance framework will contribute to data quality assurance,
# compliance, and overall data management, enhancing the reliability of analyses.
#
#
# Commented [GH10]: There is a White and Davies
# reference but not this one…
# 8.4. Integration of Predictive Analytics
# Exploring the integration of predictive analytics models can further enhance the organization's
# ability to anticipate and address emerging healthcare trends.
# 8.5. Continuous Stakeholder Engagement
# Maintaining open channels of communication with stakeholders, including healthcare
# professionals, management, and external partners, is crucial for aligning data analysis
# outcomes with organizational goals.
#
#
#
#
#
#
#
#
#
#
#
#
#
# REFERENCES
# Anderson, L. D., (2019). "Personal Growth through Data Analysis in Healthcare Settings."
# Journal of Healthcare Analytics, 6(4), 112-128.
# Brown, A. Paul, & Davis, G.  Maddison (2021). "Evolving Skillsets in Healthcare Data
# Analysis." Health Data Optimization Journal, 8(1), 45-62.
# Gupta, D. Anand (2021). "Enhancing Healthcare Data Understanding Through Visual
# Representation." Journal of Health Informatics, 8(2), 45-62.
# Garcia, R., & Martinez, S. (2020). "Statistical Approaches for Uncovering Insights in
# Healthcare Datasets." Health Data Science Journal, 5(1), 112-128.
# Kovalenko, R. Elena, & White, H. Roberts (2021). "Staying Informed: Continuous Learning
# in Healthcare Data Analysis." Health Data Science Journal, 14(3), 203-218.
# Green, S., Avery (2021). Data-Driven Decision-Making in Healthcare: A Comprehensive
# Review. Journal of Healthcare Management, 15(2), 78-94.
# Hall, M. Gabriel, & Baker, P. Carter (2020). "Effective Communication in Healthcare Data
# Analysis." Health Information Management Journal, 52(2), 87-104.
# Williams, M. Wyatt, & Evans, K. Henry (2019). "Ensuring Accuracy and Relevance in
# Healthcare Data Collection." Journal of Healthcare Analytics, 6(3), 78-92.
# Johnson, M., & Turner, L. (2017). "Enhancing Healthcare Outcomes through Personalized
# Data Analysis." Journal of Medical Informatics, 15(1), 56-73.
# Wright. C. Savannah & Martinez, S. (2020). "Ethical Considerations in Healthcare Data
# Analysis." Health Data Collaboration Review, 11(4), 78-92.
# Commented [GH11]: How are titles indicated in Harvard?
# You have use “” elsewhere but that’s wrong also. Consult the
# Harvard Referencing Guides!!!
# Commented [GH12]: No comma before &
# Lee, D. Turner, & Martin, P. Dylan (2017). "Impactful Data Reports for Informed Decision-
# Making in Healthcare Organizations." Health Information Management Journal, 48(2),
# 87-104.ar
# Nelson, A. Joseph & Smith, P. Andrew (2017). "Impactful Data Reports for Informed
# Decision-Making in Healthcare Organizations." Health Information Management
# Journal, 48(2), 87-104.
# Robinson, E., & Adams, E. (2019). "Collaboration Dynamics in Healthcare Data Analysis
# Teams." Journal of Health Informatics, 8(3), 134-150.
# Phillips, J. Harris (2019). Advancements in Healthcare Data Analysis: Implications for Patient
# Care. Journal of Health Informatics, 12(3), 45-62.
# Dubois S. Paul (2018). "Professional Networking in Healthcare Data Analysis." Journal of
# Healthcare Analytics, 5(2), 203-218.
# Parker, R. Daniel. (2021). "Extracting Meaningful Insights from Healthcare Data." Journal of
# Medical Informatics, 15(4), 203-218.
# Morgan, L., & Adams, E. (2020). "Effective Communication and Collaboration in Healthcare
# Data Analysis." Health Data Collaboration Review, 12(1), 56-73.
# Turner, R., & Martinez, A. (2022). Bridging Technology and Compassion: The Role of Data
# Analysis in Improving Patient Care. Healthcare Analytics Review, 8(1), 112-129.
# Gray, H. Miller, & Coleman, G. Brooks (2017). "Adaptability in Healthcare Data Analysis
# Strategies." Journal of Medical Informatics, 14(2), 112-128.
# White, H., & Davis, B. (2019). "Streamlining Data Analysis Workflow with Advanced Tools
# in Healthcare." Health Data Optimization Journal, 7(2), 134-150.

# %%
def extract_citations(text):
    pattern_citations = [
        r"([A-Z][a-z]+ et al\., \d{4})",
        r"([A-Z][a-z]+ et al\ \d{4})",
        r"([A-Z][a-z]+ et al\.\s?\(\d{4}\))", #removed correct et al
        r"([A-Z][a-z]+, [A-Z]\., ?et al\. \(\d{4}\))",
        r"([A-Z][a-z]+, [A-Z]\., ?et. al\. \(\d{4}\))",
        r"([A-Z][a-z]+, [A-Z]\., ?et. al\ \(\d{4}\))",
        r"([A-Z][a-z]+ et. al\., \d{4})",
        r"([A-Z][a-z]\.,+ et al\., \d{4})",
        r"([A-Z][a-z]+ et. al\, \d{4})",
        r"([A-Z][a-z]+ et. al\ \d{4})",
        r"([A-Z][a-z]+ et al\ \d{4})"
        ]

    citations = []

    for pattern in pattern_citations:
        matches = re.findall(pattern, text)
        citations.extend(matches)

    return citations

# %%
extract_citations(citation_text)
# Out:
# ['Brown et al., 2021', 'Brown et al., 2021', 'Hall et al., 2018']

# %%
def extract_in_text_citations(citation_text):
    # Define a regular expression pattern for in-text citations
    citation_pattern = global_pattern
    #citation_pattern = r"\b(?!(?:Although|In|Furthermore|Additionally|Also)\b)(?!(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\b)(?:[A-Z][A-Za-z'`-]+)(?:,? (?:(?:and |& )?(?:[Z-Z][A-Za-z'`-]+)|(?:et al.?)))*(?:,? *(?:19|20)[0-9][0-9](?:, p\.? [0-9]+)?| *\((?:19|20)[0-9][0-9](?:, p\.? [0-9]+)?\))"

    citations = re.findall(citation_pattern, citation_text)
    return citations

def extract_pattern(citation_text):
    search_pattern = global_pattern
    #search_pattern = r"\b(?!(?:Although|In|Furthermore|Additionally|Also)\b)(?!(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\b)(?:[A-Z][A-Za-z'`-]+)(?:,? (?:(?:and |& )?(?:[Z-Z][A-Za-z'`-]+)|(?:et al.?)))*(?:,? *(?:19|20)[0-9][0-9](?:, p\.? [0-9]+)?| *\((?:19|20)[0-9][0-9](?:, p\.? [0-9]+)?\))"

   
    return re.findall(search_pattern, citation_text)

# %%
global_pattern = r"\b(?!(?:Although|In|Furthermore|Additionally|Also)\b)(?!(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\b)(?:[A-Z][A-Za-z'`-]+)(?:,? (?:(?:and |& )?(?:[Z-Z][A-Za-z'`-]+)|(?:et al.?)))*(?:,? *(?:19|20)[0-9][0-9](?:, p\.? [0-9]+)?| *\((?:19|20)[0-9][0-9](?:, p\.? [0-9]+)?\))"

# %%
extract_in_text_citations(citation_text)
# Out:
# ['Dubois, 2018',
#  'Evans, 2019',
#  'Martinez, 2020',
#  'Smith, 2017',
#  'Brown et al., 2021',
#  'Davis, 2019',
#  'Adams, 2020',
#  'Phillips, 2018',
#  'Parker, 2021',
#  'Davis, 2019',
#  'Brown, 2019',
#  'Martinez, 2020',
#  'Brown et al., 2021',
#  'Nelson, 2018',
#  'Anderson, 2019',
#  'Martinez, 2020',
#  'Adams, 2019',
#  'White 2021',
#  'Baker, 2018',
#  'Martin, 2021',
#  'Martinez, 2020',
#  'Davis, 2019',
#  'Hall et al., 2018',
#  'Coleman, 2017',
#  'Green, 2018',
#  'Martinez, 2019',
#  'Adams 2017',
#  'Maddison (2021)',
#  'Anand (2021)',
#  'Roberts (2021)',
#  'Avery (2021)',
#  'Carter (2020)',
#  'Henry (2019)',
#  'Dylan (2017)',
#  'Andrew (2017)',
#  'Harris (2019)',
#  'Paul (2018)',
#  'Brooks (2017)']

# %%
def extract_pattern(citation_text):
    search_pattern = global_pattern
    #search_pattern = r"\b(?!(?:Although|In|Furthermore|Additionally|Also)\b)(?!(?:Jan(?:uary)?|Feb(?:ruary)?|Mar(?:ch)?|Apr(?:il)?|May|Jun(?:e)?|Jul(?:y)?|Aug(?:ust)?|Sep(?:tember)?|Oct(?:ober)?|Nov(?:ember)?|Dec(?:ember)?)\b)(?:[A-Z][A-Za-z'`-]+)(?:,? (?:(?:and |& )?(?:[Z-Z][A-Za-z'`-]+)|(?:et al.?)))*(?:,? *(?:19|20)[0-9][0-9](?:, p\.? [0-9]+)?| *\((?:19|20)[0-9][0-9](?:, p\.? [0-9]+)?\))"

   
    return re.findall(search_pattern, citation_text)

# %%
extract_pattern(citation_text)
# Out:
# ['Dubois, 2018',
#  'Evans, 2019',
#  'Martinez, 2020',
#  'Smith, 2017',
#  'Brown et al., 2021',
#  'Davis, 2019',
#  'Adams, 2020',
#  'Phillips, 2018',
#  'Parker, 2021',
#  'Davis, 2019',
#  'Brown, 2019',
#  'Martinez, 2020',
#  'Brown et al., 2021',
#  'Nelson, 2018',
#  'Anderson, 2019',
#  'Martinez, 2020',
#  'Adams, 2019',
#  'White 2021',
#  'Baker, 2018',
#  'Martin, 2021',
#  'Martinez, 2020',
#  'Davis, 2019',
#  'Hall et al., 2018',
#  'Coleman, 2017',
#  'Green, 2018',
#  'Martinez, 2019',
#  'Adams 2017',
#  'Maddison (2021)',
#  'Anand (2021)',
#  'Roberts (2021)',
#  'Avery (2021)',
#  'Carter (2020)',
#  'Henry (2019)',
#  'Dylan (2017)',
#  'Andrew (2017)',
#  'Harris (2019)',
#  'Paul (2018)',
#  'Brooks (2017)']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Glen\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
def find_citations_at_start(citation_text):
    citation_pattern = r"^\[[^\[\]]+\]"
    #Tokenize the text into sentences
    sentences = nltk.sent_tokenize(citation_text)
    citations_at_start = []
    # Compile the regular expression pattern
    pattern = re.compile(citation_pattern)

    # Iterate through each sentence and check for citations at the start
    for sentence in sentences:
        print(sentence)
        # Check if the sentence matches the citation pattern
        match = pattern.match(sentence)
        if match:
            citations_at_start.append(match.group())  # Extract the entire citation pattern

    return citations_at_start

# %%
find_citations_at_start(citation_text)
# Out:
# garciaTitle: Reflective Report - Data Analyst Experience at CEDAR HEALTH AND
# WELLBEING
# 1.
# Introduction
# Working as a Data Analyst at CEDAR HEALTH AND WELLBEING from August to
# December, I plunged myself into a deep and enriching experience within the healthcare field,
# with particular attention to individuals struggling with learning disabilities and Autism.
# My
# responsibilities were not limited to typical data analysis but also included the complexities of
# healthcare dynamics and how technology can interface with compassionate patient care.
# This
# reflective report aims to unravel the complex facets of my role, shedding light on the
# overarching objectives that guided my data analysis endeavours, detailing the diverse activities
# undertaken, and examining the consequential impact of my contributions to the broader
# organizational landscape.
# This transformative journey enabled me to intertwine technical proficiency with an in-depth
# comprehension of the peculiar difficulties faced by this demographic so that my analytical
# insights align with the broader purpose of improving the quality of life for individuals under
# the care of CEDAR HEALTH AND WELLBEING.
# Figure 1 showing a data analyst working
# Commented [GH1]: Please have a title Page and a TOC
# page
# Commented [GH2]: Left Justify to margin - do not
# indent...
#
# 1.1.
# Objectives of the Data Analyst Role
# In my capacity as a Data Analyst at CEDAR HEALTH AND WELLBEING, my main role was
# to identify valuable information from various datasets that are related to those who have
# learning disabilities and Autism.
# Thus, the desire to optimize all improving-care activities of
# CEDAR HEALTH AND WELLBEING becomes more and more essential in contemporary
# healthcare (Dubois, 2018).
# After a thorough examination of datasets such as patient medical
# records, treatment outcomes, and demographic data to uncover patterns, correlations, or trends
# that would inform strategic decision-making processes.
# For instance, a careful analysis of datasets concentrating on medication adherence among
# patients with learning disabilities helped me uncover patterns affecting the efficacy of
# treatments.
# Furthermore, processing demographical datasets provided a subtle insight into
# patient profiles enabling more precise tailoring of care plans to accommodate specific needs.
# Using this broad perspective in data analysis made a large contribution to the overall goal of
# enhancing healthcare approaches and consequently promoting the health conditions among
# people under CEDAR HEALTH AND WELLBEING’s.
# 2.
# Activities Undertaken
# In this section, I will outline the key activities and responsibilities undertaken during my stay
# as a Data Analyst at CEDAR HEALTH AND WELLBEING.
# 2.1.
# Data Collection and Processing
# I was also supposed to collect and process healthcare data, ensuring that it was correct and
# relevant.
# Working with the healthcare professionals, I collected information that helped me
# achieve a holistic understanding of how individuals suffering from learning disabilities and
# Autism (Williams & Evans, 2019).
# Figure 2 depicting the data analysis process.
# 2.2.
# Statistical Analysis
# By using statistical approaches, I performed thorough studies to ascertain patterns, trends, and
# correlations between the datasets.
# This statistical approach attempted to reveal insights that
# could guide decision-making processes and improve the quality of care offered by a healthcare
# organization (Garcia & Martinez, 2020).
# 2.3.
# Report Generation
# I played a pivotal role in generating reports based on the analyzed data.
# These reports were
# utilized by healthcare professionals, management, and stakeholders to assess the effectiveness
# of current practices and make informed decisions to improve the overall well-being of
# individuals in the care of CEDAR HEALTH AND WELLBEING (Lee & Smith, 2017).
# 2.4.
# Data Visualization
# To facilitate a better understanding of complex healthcare data, I engaged in data visualization
# techniques.
# Creating charts, graphs, and dashboards, I presented the findings in a visually
# comprehensible manner, aiding both technical and non-technical stakeholders in grasping the
# significance of the data (Gupta., 2021).
# To make things easier for everyone to understand the data, I used data visualization
# techniques.
# I created charts, graphs, and dashboards to present the findings more visually
# understandable form so that both technical as well as non-technical stakeholders could easily
# see the importance of data (Brown et al., 2021).
# Commented [GH3]: Why the full stop?
# 2.5.
# Continuous Improvement Initiatives
# Throughout my role, I actively engaged in initiatives aimed at improving data collection
# processes and enhancing the overall efficiency of data analysis.
# This involved collaborating
# with the IT team to implement advanced tools and technologies that streamlined the data
# analysis workflow (White & Davis, 2019).
# Figure 3 Visuals created during my time at Cedar Health and Well-being
# 3.
# Impact of Data Analysis Contributions
# The impact of my data analysis contributions on CEDAR HEALTH AND WELLBEING and
# the individuals under its care is noteworthy, encompassing various facets of organizational and
# patient outcomes.
# 3.1.
# Enhanced Decision-Making
# The provision of accurate and insightful data analyses significantly contributed to informed
# decision-making processes within the organization (Morgan & Adams, 2020).
# These analyses
# played a pivotal role in shaping healthcare strategies tailored for individuals with learning
# disabilities and Autism.
# I remember, in a specific unit catering to individuals with Autism, the healthcare team noticed
# variations in treatment responses among patients undergoing a particular therapeutic
# intervention.
# I and some colleagues, through rigorous analysis of patient records, identified
# patterns indicating that individuals with certain learning disabilities responded more positively
# to alternative therapies.
# This insight prompted the healthcare team to reassess their approach
# and consider personalized therapeutic plans based on the specific needs and responsiveness of
# each individual.
# By tailoring interventions to align with the data-driven findings, the team
# observed improved outcomes, reduced adverse effects, and enhanced patient satisfaction.
# 3.2.
# Improved Patient Care
# The data-driven insights derived from my analyses played a crucial role in enhancing the
# quality of patient care (Phillips, 2018).
# Healthcare professionals were empowered to tailor
# interventions based on individual needs, fostering a more personalized and effective care
# approach.
# 3.3.
# Efficiency Gains
# A continuous improvement strategy was implemented that improved the efficiency of data
# analysis workflow, saving time and providing rapid response to emerging healthcare trends and
# challenges (Parker, 2021).
# 3.4.
# Positive Organizational Impact
# The reports and visualizations generated during my when I was a Data Analyst there had a
# positive impact on the organization (White & Davis, 2019).
# Stakeholders, including
# management and external partners, gained a clearer understanding of the organization's
# performance and its commitment to data-driven decision-making.
# Figure 4 showing the positive outcomes through my data analysis
# 4.
# Reflection
# Reflecting on my experience as a Data Analyst at CEDAR HEALTH AND WELLBEING
# reveals key insights and personal growth areas that have contributed to both my professional
# and personal development.
# My professional life in data analysis at CEDAR HEALTH AND
# WELLBEING was a period of significant personal and career growth.
# While being a
# challenging immersion, it turned out to be very rewarding as I gained an in-depth set of skills
# in data analytics and insight generation.
# I polished my skills in statistical analysis tools, data processing techniques, and methods of
# data visualization while navigating through different datasets in the field of healthcare.
# Data
# cleansing and the complexity surrounding data quality became a vital concern, reflective of the
# complications arising from comprehensiveness with healthcare data.
# Working with healthcare professionals and the larger team required strong communication
# skills.
# Subsequently, regular meetings and feedback sessions became the basis for matching
# data analysis outcomes with the organization’s healthcare goals.
# This collaborative approach
# not only made me better prepared to present complicated analytical findings but also facilitated
# an engaging creative fusion between the technical and non-technical stakeholders.
# Healthcare
# data analysis was also dynamic, and therefore they required problem-solving skills as well as
# effective time use.
# Juggling multiple tasks and deadlines turned into second nature as I
# endeavored to streamline the processes of data interpretation, while also being prompt when it
# came to adapting my responses based on new developments in healthcare.
# Thus, my work as a Data Analyst at CEDAR HEALTH AND WELLBEING could be described
# best in terms of a transformative journey that is both challenging and rewarding in healthcare
# dynamics.
# 4.1.
# Technical Skill Development
# The role provided a platform for enhancing technical skills in data analysis, statistical methods,
# and data visualization tools (Johnson & Brown, 2019).
# Navigating through diverse datasets
# improved my proficiency in extracting meaningful insights.
# Healthcare data, like most things in the healthcare sector, is dynamic and no issue would be
# handled without taking into consideration several things including subtle patterns and trends
# emerging from meticulous analysis.
# Statistical methods were applied not only as a regime of
# abstract thought but also as an essential instrument that shaped the strategic direction for
# decisions regarding healthcare interventions.
# It was like a crucible, within which the art of
# distilling meaningful information from such datasets could be finely honed while combining
# technical expertise with a more significant aim to increase quality in care delivered by
# CEDARHEALTH AND WELLBEING.
# It also highlighted the critical intersection between
# developing technical skills and realizing the immediate effects of data-guided decisions in
# healthcare.
# 4.2.
# Understanding Healthcare Dynamics
# Interacting with healthcare professionals improved my knowledge about the complex aspects
# of providing care to people suffering from learning disabilities and Autism (Nelson & Smith,
# 2017).
# This experience widened my outlook concerning the link between data and healthcare
# delivery.
# For instance, in particular cases such as discussions with healthcare professionals’ a
# certain case was observed when practice data analysis of patient records demonstrated patterns
# in the effectiveness of the use of different intervention strategies.
# This real-life case showed
# how insights from data improved and perfected the care planning for individuals with learning
# disabilities.
# Such occurrences emphasized the importance of my position as a Data Analyst in
# enhancing healthcare outcomes.
# Commented [GH4]: This is a bit repetitive and not sure
# why it is all capitalised...
# 4.3.
# Challenges Encountered
# Challenges involved in navigating the healthcare data included the need for thorough data
# cleansing and addressing data quality issues (Garcia & Martinez, 2020).
# Overcoming these
# challenges strengthened my problem-solving skills and resilience.
# One particular case happened when dealing with discrepancies in the patient records, where
# inconsistent
# data
# entry
# adversely
# affected
# the
# results
# of
# the
# analysis.
# To tackle this problem, I worked closely with the IT team and healthcare professionals in
# implementing a strict data-cleaning procedure.
# This real-life case demonstrated that poor data
# quality directly translated into unreliable analytical results.
# Through thorough data validation
# steps and ongoing improvements, we managed to boost the precision of our analytical insights
# so that not merely were they meaningful but also trustworthy.
# 4.4.
# Time Management and Prioritization
# The dynamic nature of healthcare data analysis requires effective time management and
# prioritization (Brown et al., 2021).
# Balancing multiple tasks and deadlines improved my ability
# to prioritize and manage time efficiently.
# One important project concerned the urgent situation of analyzing a large dataset with
# significant data that pertained to the medication preferences of people suffering from learning
# disabilities.
# In parallel, another project aimed at evaluating the effectiveness of current data
# collection practices was developing.
# This situation necessitated careful planning and ranking
# of priorities.
# To address this problem, I used a systematic method.
# First, I did a thorough evaluation of both
# projects to determine the priorities and their respective deadlines.
# Because the medication
# preferences analysis is time-sensitive, I allotted particular windows of my day to immerse
# myself into such a dataset in order not to be distracted by other issues and to carry out this
# analysis promptly.
# Also, there was a strategic timing for the data collection efficiency project
# when some periods of lesser urgency were allocated allowing balance and order in the
# works.
# Management of time effectively This real-world application in both projects not only
# led to their completion successfully but also highlighted the significance that adaptability can
# play when dealing with changing requirements for healthcare data analysis.
# This experience
# greatly developed my ability to handle several tasks without sacrificing the quality of work.
# 4.5.
# Collaboration and Communication
# The role depended on effective collaboration and communication with the healthcare
# professionals.
# I managed to overcome communication barriers and customize how data were
# presented to stakeholders, thus developing my interpersonal skills as well as my ability to
# communicate effectively (Robinson & Nelson, 2018).
# 4.6.
# Personal Growth
# I achieved significant personal growth from the experience at CEDAR HEALTH AND
# WELLBEING.
# During the process, I learned to deal responsibly with sensitive healthcare data
# and developed a new understanding of how important it is to analyze data to guide health
# outcomes (Anderson, 2019).
# 5.
# Personal Benefits
# Working as a Data Analyst at CEDAR HEALTH AND WELLBEING yielded numerous
# personal benefits that extend beyond technical skills.
# 5.1.
# Sense of Purpose
# A huge sense of purpose came from contributing to improved health outcomes for people with
# learning disabilities and Autism.
# It was fulfilling, personally for me to know that my analyses
# contributed to the betterment of their quality of life.
# 5.2.
# Skill Diversification
# The role allowed for the diversification of skills beyond technical competencies.
# I gained
# insights into healthcare administration, compliance, and the ethical considerations surrounding
# healthcare data (Wright & Martinez, 2020).
# 5.3.
# Professional Networking
# Communicating with healthcare professionals created potentially beneficial professional
# relationships.
# Working with various teams expanded my circle of acquaintances and
# familiarized me with terms within the healthcare industry (Robinson & Adams, 2019).
# 5.4.
# Continuous Learning
# Due to the dynamic nature of healthcare data and changing trends in the industry, continuous
# learning was required.
# As the field of data analysis methodologies and healthcare practices
# continued to shift, staying up-to-date helped me remain mentally engaged.
# (Kovalenko &
# White 2021).
# This helped me stay intellectually stimulated by following developments in both
# data analysis methodologies and healthcare practices (Hall & Baker, 2018).
# 6.
# Professional Values and Behaviour
# In this section, I will discuss the professional values and behavior exhibited during my role as
# a Data Analyst at CEDAR HEALTH AND WELLBEING.
# 6.1.
# Integrity and Ethics
# Maintaining the highest standards of integrity and ethics was paramount in handling healthcare
# data.
# Adhering to privacy regulations and ensuring the ethical use of data underscored the trust
# placed in the data analysis process (Lee & Martin, 2021).
# For instance, maintaining high standards of integrity and ethics as a Data Analyst at CEDAR
# HEALTH AND WELLBEING in practice meant putting stringent mechanisms to safeguard
# private healthcare information.
# I remember, when working with patient records and treatment
# information I always made certain that privacy regulations like the Health Insurance Portability
# and Accountability Act (HIPAA) were maintained.
# This encompassed the use of encryption
# protocols for data storage, limiting access to personnel authorized; regular audits were also
# done to point out possible vulnerabilities in the system and remedy them.
# In addition, I was actively involved in the formulation and implementation of organizational
# policies that centered on the ethical use of data.
# For example, when faced with a situation where
# divulging specific data could potentially compromise patient confidentiality, I argued for one
# that would be more secure and privacy-preserving.
# This dedication to ethical decision-making,
# not only aligned with the guidelines of industry regulations but also showed a forward-thinking
# attitude in being a trustworthy and confident worthy organization as well pupils were under its
# care.
# Commented [GH5]: British english…
# 6.2.
# Collaboration and Teamwork
# Teamwork was demonstrated through collaboration with healthcare professionals and other
# team members.
# Open communication and the spirit of collaboration were crucial to successful
# data analysis projects (Johnson & Martinez, 2020; Robinson& Davis, 2019).
# 6.3.
# Accountability
# Taking accountability for the accuracy and reliability of data analyses demonstrated a
# commitment to delivering high-quality insights.
# This accountability extended to addressing any
# discrepancies and continuously improving data quality (Hall et al., 2018; Anderson & Turner,
# 2020).
# 6.4.
# Adaptability
# The healthcare sector's dynamic nature requires adaptability to changing circumstances.
# Embracing change and adapting data analysis strategies to evolving healthcare needs
# showcased flexibility and resilience (Gray & Coleman, 2017).
# 6.5.
# Continuous Improvement
# Engaging in continuous improvement initiatives highlighted a commitment to enhancing
# processes and outcomes.
# A proactive approach to identifying areas for improvement
# contributed to the organization's overall growth (Green, 2018).
# Commented [GH6]: space
# Commented [GH7]: et al.
# Commented [GH8R7]: But only for more than three
# authors
# 7.
# Conclusion
# In the end, the period I worked as a Data Analyst at CEDAR HEALTH AND WELLBEING
# was an enriching journey combining strong technical skills and a deep understanding of
# complex healthcare processes.
# This role was not simply about applying and polishing data
# analysis skills; it served as a fire where personal and professional development could take place
# on an expansive scale.
# The resulting impact of data-based decision-making on patient care,
# organizational effectiveness, and the overall healthcare strategy inherently highlights how
# paramount this practice is within the healthcare sector.
# Without a doubt, the various tasks I performed during my time there highlighted the hands-on
# nature of data analytics in defining healthcare outcomes.
# The depth and scope of that which
# was analyzed together with the strategic insights found were instrumental in informed decision-
# making processes.
# This was not just an issue for the organizational hierarchy but profoundly
# influenced strategies that were formulated at all levels to cater to individuals who received care
# from CEDAR HEALTH AND WELLBEING.
# The congruence between data analysis and
# healthcare strategies became manifest as a tangible improvement in the quality of patient care,
# reflective both of technical awareness on one hand and compassionate provisioning on the other
# (Turner & Martinez, 2019)
# This highlights the dynamic interaction of technical knowledge, human interactive skills as
# well as a high level of responsibility to be able to work with confidential data about health.
# This
# experience indicates the crucial position that data analysts hold in directing healthcare
# organizations toward attaining maximum benefits when such critical transformations occur
# within the health industry, where untold levels of innovation and basic metamorphosis are
# apparent.
# This journey was also instrumental in obtaining a wise understanding of healthcare
# ideas and implanting a very resilient ethic, that is the capacity to react constructively to
# Commented [GH9]: Make Headings larger font
# challenges while meaningfully contributing to noble causes aimed at healthcare quality
# betterment (White & Adams 2017).
# In sum, the role of a Data Analyst at CEDAR HEALTH AND WELLBEING was more than
# just a stage of professional growth, it was also a vibrant diverse experience for all sorts of
# technical acumen and compassionate care delivery that resonated on organizational, strategic,
# and personal levels.
# 8.
# Recommendations for Future Data Analysis Initiatives
# Based on my experience, I recommend the following for future data analysis initiatives at
# CEDAR HEALTH AND WELLBEING:
# 8.1.
# Advanced Training
# Providing continuous training opportunities in advanced data analysis methodologies and tools
# will empower analysts to stay at the forefront of industry advancements.
# 8.2.
# Interdepartmental Collaboration
# Encouraging increased collaboration between the data analysis team and various healthcare
# departments will ensure a more comprehensive understanding of data needs and facilitate more
# targeted analyses.
# 8.3.
# Data Governance Framework
# Establishing a robust data governance framework will contribute to data quality assurance,
# compliance, and overall data management, enhancing the reliability of analyses.
# Commented [GH10]: There is a White and Davies
# reference but not this one…
# 8.4.
# Integration of Predictive Analytics
# Exploring the integration of predictive analytics models can further enhance the organization's
# ability to anticipate and address emerging healthcare trends.
# 8.5.
# Continuous Stakeholder Engagement
# Maintaining open channels of communication with stakeholders, including healthcare
# professionals, management, and external partners, is crucial for aligning data analysis
# outcomes with organizational goals.
# REFERENCES
# Anderson, L. D., (2019).
# "Personal Growth through Data Analysis in Healthcare Settings."
# Journal of Healthcare Analytics, 6(4), 112-128.
# Brown, A. Paul, & Davis, G.  Maddison (2021).
# "Evolving Skillsets in Healthcare Data
# Analysis."
# Health Data Optimization Journal, 8(1), 45-62.
# Gupta, D. Anand (2021).
# "Enhancing Healthcare Data Understanding Through Visual
# Representation."
# Journal of Health Informatics, 8(2), 45-62.
# Garcia, R., & Martinez, S. (2020).
# "Statistical Approaches for Uncovering Insights in
# Healthcare Datasets."
# Health Data Science Journal, 5(1), 112-128.
# Kovalenko, R. Elena, & White, H. Roberts (2021).
# "Staying Informed: Continuous Learning
# in Healthcare Data Analysis."
# Health Data Science Journal, 14(3), 203-218.
# Green, S., Avery (2021).
# Data-Driven Decision-Making in Healthcare: A Comprehensive
# Review.
# Journal of Healthcare Management, 15(2), 78-94.
# Hall, M. Gabriel, & Baker, P. Carter (2020).
# "Effective Communication in Healthcare Data
# Analysis."
# Health Information Management Journal, 52(2), 87-104.
# Williams, M. Wyatt, & Evans, K. Henry (2019).
# "Ensuring Accuracy and Relevance in
# Healthcare Data Collection."
# Journal of Healthcare Analytics, 6(3), 78-92.
# Johnson, M., & Turner, L. (2017).
# "Enhancing Healthcare Outcomes through Personalized
# Data Analysis."
# Journal of Medical Informatics, 15(1), 56-73.
# Wright.
# C. Savannah & Martinez, S. (2020).
# "Ethical Considerations in Healthcare Data
# Analysis."
# Health Data Collaboration Review, 11(4), 78-92.
# Commented [GH11]: How are titles indicated in Harvard?
# You have use “” elsewhere but that’s wrong also.
# Consult the
# Harvard Referencing Guides!!!
# Commented [GH12]: No comma before &
# Lee, D. Turner, & Martin, P. Dylan (2017).
# "Impactful Data Reports for Informed Decision-
# Making in Healthcare Organizations."
# Health Information Management Journal, 48(2),
# 87-104.ar
# Nelson, A. Joseph & Smith, P. Andrew (2017).
# "Impactful Data Reports for Informed
# Decision-Making in Healthcare Organizations."
# Health Information Management
# Journal, 48(2), 87-104.
# Robinson, E., & Adams, E. (2019).
# "Collaboration Dynamics in Healthcare Data Analysis
# Teams."
# Journal of Health Informatics, 8(3), 134-150.
# Phillips, J. Harris (2019).
# Advancements in Healthcare Data Analysis: Implications for Patient
# Care.
# Journal of Health Informatics, 12(3), 45-62.
# Dubois S. Paul (2018).
# "Professional Networking in Healthcare Data Analysis."
# Journal of
# Healthcare Analytics, 5(2), 203-218.
# Parker, R. Daniel.
# (2021).
# "Extracting Meaningful Insights from Healthcare Data."
# Journal of
# Medical Informatics, 15(4), 203-218.
# Morgan, L., & Adams, E. (2020).
# "Effective Communication and Collaboration in Healthcare
# Data Analysis."
# Health Data Collaboration Review, 12(1), 56-73.
# Turner, R., & Martinez, A.
# (2022).
# Bridging Technology and Compassion: The Role of Data
# Analysis in Improving Patient Care.
# Healthcare Analytics Review, 8(1), 112-129.
# Gray, H. Miller, & Coleman, G. Brooks (2017).
# "Adaptability in Healthcare Data Analysis
# Strategies."
# Journal of Medical Informatics, 14(2), 112-128.
# White, H., & Davis, B.
# (2019).
# "Streamlining Data Analysis Workflow with Advanced Tools
# in Healthcare."
# Health Data Optimization Journal, 7(2), 134-150.
# []

# %%
import re

def find_harvard_citations_one_author(text):
    pattern = r'\(\w+\s?,\s?\d{4}\)'  # Regular expression pattern for Harvard-style citations like (Author, Year)
    citations = re.findall(pattern, text)
    return citations

# Example text
paper_text = "According to Smith, (2020) this was a significant finding. Previous research (Johnson, 2018) also supported these results."

# Finding Harvard-style citations in the example text
found_citations1 = find_harvard_citations_one_author(paper_text)

# Displaying the found citations
print("Found Harvard-style citations:", found_citations1)
# Out:
# Found Harvard-style citations: ['(Johnson, 2018)']

# %%
def find_harvard_citations_two_authors(text):
    pattern = r'\(\w+\s?&\s?\w+,\s?\d{4}\)'  # Regular expression pattern for Harvard-style citations with two authors like (Author1 & Author2, Year)
    citations = re.findall(pattern, text)
    return citations

# Example text
paper_text = "According to Smith & Johnson (2020) this was a significant finding. Previous research (Brown & White, 2018) also supported these results."

# Finding Harvard-style citations with two authors in the example text 
found_citations2 = find_harvard_citations_two_authors(paper_text)

# Displaying the found citations
print("Found Harvard-style citations with two authors:", found_citations2)
# Out:
# Found Harvard-style citations with two authors: ['(Brown & White, 2018)']

# %%
foud_citationsall = found_citations1 + found_citations2

# %%
print (foud_citationsall)
# Out:
# ['(Johnson, 2018)', '(Brown & White, 2018)']

# %%
def find_harvard_citations_three_authors(text):
    pattern = r'\(\w+\s?,\s?\w+\s?&\s?\w+,\s?\d{4}\)'  # Regular expression pattern for Harvard-style citations with three authors like (Author1, Author2 & Author3, Year)
    citations = re.findall(pattern, text)
    return citations

# Example text
paper_text = "According to Smith, Johnson & Williams (2020) this was a significant finding. Previous research (Brown, White & Black, 2018) also supported these results."

# Finding Harvard-style citations with three authors in the example text
found_citations = find_harvard_citations_three_authors(citation_text)

# Displaying the found citations
print("Found Harvard-style citations with three authors:", found_citations)
# Out:
# Found Harvard-style citations with three authors: []

# %%
import re

def find_harvard_citations_et_al(text):
    pattern = r'\(\w+\s?(?:,?\s?\w+)?(?:,?\s?\w+)?\s?et al.,\s?\d{4}\)'  # Regular expression pattern for Harvard-style citations with "et al." like (Author1 et al., Year)
    citations = re.findall(pattern, text)
    return citations

# Example text
paper_text = "According to Smith et al. (2020) this was a significant finding. Previous research (Brown, White, Black et al., 2018) also supported these results."

# Finding Harvard-style citations with "et al." in the example text
found_citations = find_harvard_citations_et_al(citation_text)

# Displaying the found citations
print("Found Harvard-style citations with 'et al.':", found_citations)
# Out:
# Found Harvard-style citations with 'et al.': ['(Brown et al., 2021)', '(Brown et al., 2021)']

# %%
def find_author_year_citations(text):
    pattern = r'\b\w+\s?\(\d{4}\)'  # Regular expression pattern for citations in the format "Author (Year)"
    citations = re.findall(pattern, text)
    return citations

# Example text containing citations in the "Author (Year)" format 
paper_text = "According to Smith (2020), this was a significant finding. Another study mentioned Johnson (2018) as a reference for their work."

# Finding citations in the "Author (Year)" format within the example text 
found_citations = find_author_year_citations(paper_text)

# Displaying the found citations
print("Found citations in the 'Author (Year)' format:", found_citations)
# Out:
# Found citations in the 'Author (Year)' format: ['Smith (2020)', 'Johnson (2018)']

# %%
import re

def find_author_and_author_year_citations(text):
    pattern = r'\b\w+\s?&\s?\w+\s?\(\d{4}\)'  # Regular expression pattern for citations in the format "Author & Author (Year)"
    citations = re.findall(pattern, text)
    return citations

# Example text containing citations in the "Author & Author (Year)" format 
paper_text = "According to Smith & Johnson (2020), this was a significant finding. Another study mentioned Brown & White (2018) as a reference for their work."

# Finding citations in the "Author & Author (Year)" format within the example text 
found_citations = find_author_and_author_year_citations(paper_text)

# Displaying the found citations
print("Found citations in the 'Author & Author (Year)' format:", found_citations)
# Out:
# Found citations in the 'Author & Author (Year)' format: ['Smith & Johnson (2020)', 'Brown & White (2018)']

# %%
import re

def find_author_comma_author_and_author_year_citations(text):
    pattern = r'\b\w+\s?,\s?\w+\s?&\s?\w+\s?\(\d{4}\)'  # Regular expression pattern for citations in the format "Author, Author & Author (Year)"
    citations = re.findall(pattern, text)
    return citations

# Example text containing citations in the "Author, Author & Author (Year)" format
paper_text = "According to Smith, Johnson & Williams (2020), this was a significant finding. Another study mentioned Brown, White & Black (2018) as a reference for their work."

# Finding citations in the "Author, Author & Author (Year)" format within the example text
found_citations = find_author_comma_author_and_author_year_citations(paper_text)

# Displaying the found citations
print("Found citations in the 'Author, Author & Author (Year)' format:", found_citations)
# Out:
# Found citations in the 'Author, Author & Author (Year)' format: ['Smith, Johnson & Williams (2020)', 'Brown, White & Black (2018)']

# %%
import re

def find_author_et_al_year_citations(text):
    pattern = r'\b\w+\s?et\s?al\.\s?\(\d{4}\)'  # Regular expression pattern for citations in the format "Author et al. (Year)"
    citations = re.findall(pattern, text)
    return citations

# Example text containing citations in the "Author et al. (Year)" format 
paper_text = "According to Smith et al. (2020), this was a significant finding. Another study mentioned Johnson et al. (2018) as a reference for their work."

# Finding citations in the "Author et al. (Year)" format within the example text 
found_citations = find_author_et_al_year_citations(paper_text)

# Displaying the found citations
print("Found citations in the 'Author et al. (Year)' format:", found_citations)
# Out:
# Found citations in the 'Author et al. (Year)' format: ['Smith et al. (2020)', 'Johnson et al. (2018)']

# %%
def find_all_citations (text):
    citations = find_harvard_citations_one_author(paper_text)
    citations = citations + find_harvard_citations_two_authors(text)
    citations = citations + find_harvard_citations_three_authors(text)
    citations = citations + find_harvard_citations_et_al(text)
    citations = citations + find_author_year_citations(text)
    citations = citations + find_author_and_author_year_citations(text)
    citations = citations + find_author_comma_author_and_author_year_citations(text)
    citations = citations + find_author_et_al_year_citations(text)
    return citations

# %%
import findcitations
print (findcitations.find_all_citations (citation_text))
# Out:
# ['(Dubois, 2018)', '(Phillips, 2018)', '(Parker, 2021)', '(Anderson, 2019)', '(Green, 2018)', '(Williams & Evans, 2019)', '(Garcia & Martinez, 2020)', '(Lee & Smith, 2017)', '(White & Davis, 2019)', '(Morgan & Adams, 2020)', '(White & Davis, 2019)', '(Johnson & Brown, 2019)', '(Garcia & Martinez, 2020)', '(Robinson & Nelson, 2018)', '(Wright & Martinez, 2020)', '(Robinson & Adams, 2019)', '(Hall & Baker, 2018)', '(Lee & Martin, 2021)', '(Gray & Coleman, 2017)', '(Turner & Martinez, 2019)', '(Brown et al., 2021)', '(Brown et al., 2021)', 'Maddison (2021)', 'Anand (2021)', 'Roberts (2021)', 'Avery (2021)', 'Carter (2020)', 'Henry (2019)', 'Dylan (2017)', 'Andrew (2017)', 'Harris (2019)', 'Paul (2018)', 'Brooks (2017)']
